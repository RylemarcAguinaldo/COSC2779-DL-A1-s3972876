# %% [markdown]
# # COSC2779 DL Assignments 1: Introduction to Deep Convolutional Neural Networks
#
# **Name:** Rylemarc Jade Aguinaldo
# **Student Number:** s3972876

# %% [markdown]
# ## Imports and Device Configuration

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Subset
import matplotlib.pyplot as plt
import numpy as np

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')
# Out:
# Using device: cuda

# %% [markdown]
# ## Dataset initialisation

# %% [markdown]
# ### Load Dataset

# %%
import os
import random
import zipfile
from collections import defaultdict
from PIL import Image
from torch.utils.data import Dataset
from torchvision import transforms

ZIP_PATH = 'A1_data_2026.zip'
DATA_DIR = './data_resized/data_resized'

# ---- Extract zip file ----
if not os.path.isdir(DATA_DIR):
    with zipfile.ZipFile(ZIP_PATH, 'r') as z:
        z.extractall(DATA_DIR)
    print('Extracted to', DATA_DIR)


class CustomFolderDataset(Dataset):
    def __init__(self, samples, transform=None):
        """
        samples: List of (image_path, class_index) tuples
        """
        self.samples = samples
        self.transform = transform

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        path, target = self.samples[idx]
        img = Image.open(path).convert('RGB')
        if self.transform is not None:
            img = self.transform(img)
        return img, target


def load_and_split_dataset(root, class_names, train_ratio=0.8, seed=42):
    random.seed(seed)
    
    # Resolve nested extraction folders
    actual_root = root
    while True:
        subdirectories = [
            d for d in os.listdir(actual_root) 
            if os.path.isdir(os.path.join(actual_root, d)) and not d.startswith('.')
        ]
        if len(subdirectories) == 1 and (subdirectories[0] not in class_names):
            actual_root = os.path.join(actual_root, subdirectories[0])
        else:
            break

    class_to_idx = {cls_name: i for i, cls_name in enumerate(class_names)}
    valid_exts = ('.png', '.jpg', '.jpeg', '.bmp', '.webp')

    # Structure: class_idx -> dict(instance_dir_path -> list_of_image_paths)
    class_instances = defaultdict(lambda: defaultdict(list))

    for class_name in class_names:
        class_dir = os.path.join(actual_root, class_name)
        if not os.path.isdir(class_dir):
            continue

        target_idx = class_to_idx[class_name]
        
        # Traverse down to Instance level
        for dirpath, _, filenames in os.walk(class_dir):
            image_files = [f for f in filenames if f.lower().endswith(valid_exts)]
            if image_files:
                # Group images by their parent directory (Instance folder)
                for fname in image_files:
                    img_path = os.path.join(dirpath, fname)
                    class_instances[target_idx][dirpath].append((img_path, target_idx))

    train_samples, val_samples = [], []

    # Perform stratified split on instance level per class
    for target_idx, instances_dict in class_instances.items():
        instance_dirs = list(instances_dict.keys())
        random.shuffle(instance_dirs)
        
        split_cutoff = int(len(instance_dirs) * train_ratio)
        train_dirs = instance_dirs[:split_cutoff]
        val_dirs = instance_dirs[split_cutoff:]

        # Collect all 5 images for each assigned instance
        for inst_dir in train_dirs:
            train_samples.extend(instances_dict[inst_dir])
        for inst_dir in val_dirs:
            val_samples.extend(instances_dict[inst_dir])

    return train_samples, val_samples


# ---- Configuration & Execution ----
CLASS_NAMES = [
    'AllClear', 'HaveCommand', 'Hover', 'Land', 'LandingDirection', 
    'MoveAhead', 'MoveDownward', 'MoveToLeft', 'MoveToRight', 'MoveUpward', 
    'NotClear', 'SlowDown', 'WaveOff'
]

base_transform = transforms.Compose([
    transforms.ToTensor(),
])

# Perform 80/20 train/val split by instance
train_samples, val_samples = load_and_split_dataset(
    root=DATA_DIR,
    class_names=CLASS_NAMES,
    train_ratio=0.8,
    seed=42
)

# Create train and val PyTorch Datasets
train_dataset = CustomFolderDataset(train_samples, transform=base_transform)
val_dataset = CustomFolderDataset(val_samples, transform=base_transform)

print(f"Train dataset size: {len(train_dataset)} images ({len(train_dataset) // 5} instances)")
print(f"Val dataset size:   {len(val_dataset)} images ({len(val_dataset) // 5} instances)")
# Out:
# Train dataset size: 4210 images (842 instances)
# Val dataset size:   1085 images (217 instances)
