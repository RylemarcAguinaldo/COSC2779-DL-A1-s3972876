# %% [markdown]
# # COSC2779 DL Assignments 1: Introduction to Deep Convolutional Neural Networks
#
# **Name:** Rylemarc Jade Aguinaldo
# **Student Number:** s3972876

# %% [markdown]
# # Part A: Build the Classifier

# %% [markdown]
# ## Imports and Device Configuration

# %% [markdown]
# ### Install dependencies and packages

# %%
# %pip install torch torchvision matplotlib numpy scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
# For local PC
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Subset
import matplotlib.pyplot as plt
import numpy as np

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')

# Have a set seed for model - eliminates any variation
torch.manual_seed(42)
# Out:
# Using device: cuda

# %% [markdown]
# ## Dataset initialisation

# %% [markdown]
# ### Load Dataset

# %%
import os
import re
import zipfile
from PIL import Image
from torch.utils.data import Dataset
from torchvision import transforms

ZIP_PATH = 'A1_data_2026.zip'
DATA_DIR = './data_resized/data_resized'

# ---- Extract zip file ----
if not os.path.isdir(DATA_DIR):
    with zipfile.ZipFile(ZIP_PATH, 'r') as z:
        z.extractall(DATA_DIR)
    print('Extracted to', DATA_DIR)

def load_dataset(root, class_names):
    actual_root = root
    while True:
        subdirectories = [
            d for d in os.listdir(actual_root) 
            if os.path.isdir(os.path.join(actual_root, d)) and not d.startswith('.')
        ]
        if len(subdirectories) == 1 and (subdirectories[0] not in class_names):
            actual_root = os.path.join(actual_root, subdirectories[0])
        else:
            break

    class_to_idx = {cls_name: i for i, cls_name in enumerate(class_names)}
    valid_exts = ('.png', '.jpg', '.jpeg', '.bmp', '.webp')

    all_samples = []
    class_indices = []
    groups = []

    # Example: S13_allClear_HD_instance1_1.jpg
    # Group 1: Subject (S13)
    # Group 2: Gesture Class (allClear)
    # Group 3: Instance ID (instance1)
    pattern = re.compile(r'^(S\d+)_([a-zA-Z0-9]+)_(?:HD_)?(instance\d+)_\d+', re.IGNORECASE)

    for class_name in class_names:
        class_dir = os.path.join(actual_root, class_name)
        if not os.path.isdir(class_dir):
            continue

        target_idx = class_to_idx[class_name]

        for dirpath, dirnames, filenames in os.walk(class_dir):
            # Exclude checkpoint/hidden directories from further traversal
            dirnames[:] = [d for d in dirnames if not d.startswith('.')]
            for fname in filenames:
                if fname.lower().endswith(valid_exts):
                    img_path = os.path.join(dirpath, fname)
                    
                    match = pattern.match(fname)
                    if match:
                        subject, gesture, instance = match.groups()
                        # Group key combines Subject + Gesture + Instance (e.g., 'S13_alLClear_instance1')
                        group_key = f"{subject}_{gesture}_{instance}"
                    else:
                        # Fallback if filename format varies slightly
                        group_key = os.path.splitext(fname)[0].rsplit('_', 1)[0]

                    all_samples.append((img_path, target_idx))
                    class_indices.append(target_idx)
                    groups.append(group_key)

    return all_samples, class_indices, groups

# %% [markdown]
# ### Get images from dataset

# %% [markdown]
# In order to train the model to classify gestures based on instances, the image loader function is designed **to stack five images from the same instance along the channel dimension to form a single image.** This allows for models to process grouped images as a instance rather than individual frames.
# https://www.youtube.com/watch?v=A9D6NXBJdwU&t=1s
#
# For some EDA tasks (i.e. visualising instances for each class), a function which only loads individual images will be used instead for simplicity.

# %%
class singleImageLoader(Dataset):
    def __init__(self, samples, transform=None):
        """
        samples: List of (image_path, class_index) tuples
        """
        self.samples = samples
        self.transform = transform

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        path, target = self.samples[idx]
        img = Image.open(path).convert('RGB')
        if self.transform is not None:
            img = self.transform(img)
        return img, target


from collections import defaultdict
import torch

class stackedImageLoader(Dataset):
    def __init__(self, samples, transform=None, synchronized=False):
        """
        samples: List of (image_path, class_index, group_key) tuples —
                 one row per FRAME. Frames sharing the same group_key
                 are grouped into a single stacked clip.
        """
        self.transform = transform
        self.synchronized = synchronized

        # Group frame paths by instance (group_key)
        grouped = defaultdict(list)
        labels = {}
        for path, target, group_key in samples:
            grouped[group_key].append(path)
            labels[group_key] = target

        # Sort frames within each instance so temporal order is consistent
        # (assumes filenames sort correctly, e.g. ..._1.jpg ... ..._5.jpg)
        self.instances = []
        for group_key, paths in grouped.items():
            paths_sorted = sorted(paths)
            self.instances.append((paths_sorted, labels[group_key], group_key))

    def __len__(self):
        return len(self.instances)

    def __getitem__(self, idx):
        paths, target, group_key = self.instances[idx]

        # Load all five frames as a list
        frames = [Image.open(p).convert('RGB') for p in paths]

        if self.transform is not None:
            if self.synchronized:
                # Transform expects the whole list, decides randomness once, returns stacked tensor
                clip = self.transform(frames)
            else:
                # Transform expects one image at a time (e.g. deterministic resize/normalize for val)
                frames = [self.transform(f) for f in frames]
                clip = torch.stack(frames)
        else:
            clip = torch.stack([TF.to_tensor(f) for f in frames])
    
        return clip, target

# %% [markdown]
# ## Exploratory Data Analysis - Pre-split

# %% [markdown]
# ### Image + Instance count

# %%
# ---- Class Distribution of Full Dataset ----
CLASS_NAMES = [
    'AllClear', 'HaveCommand', 'Hover', 'Land', 'LandingDirection', 
    'MoveAhead', 'MoveDownward', 'MoveToLeft', 'MoveToRight', 'MoveUpward', 
    'NotClear', 'SlowDown', 'WaveOff'
]

samples, class_indices, groups = load_dataset(root=DATA_DIR, class_names=CLASS_NAMES)

print(f'Image count: {len(samples)}')
print(f'Instance count: {len(samples) / 5}')
# Out:
# Image count: 5301
# Instance count: 1060.2

# %% [markdown]
# ### Visualise instances for each class

# %%
# Visualise one instance (5 images) per class
import random

paths = [s[0] for s in samples]
labels = [s[1] for s in samples]

# Re-derive group key per training sample using the same regex/logic as load_dataset
import re
pattern = re.compile(r'^(S\d+)_([a-zA-Z0-9]+)_(?:HD_)?(instance\d+)_\d+', re.IGNORECASE)

def get_group_key(path):
    fname = os.path.basename(path)
    match = pattern.match(fname)
    if match:
        subject, gesture, instance = match.groups()
        return f"{subject}_{gesture}_{instance}"
    return os.path.splitext(fname)[0].rsplit('_', 1)[0]

# For each class, pick one group (instance) at random
class_to_group = {}
for path, label, group in zip(paths, labels, groups):
    if label not in class_to_group:
        candidates = [g for p, l, g in zip(paths, labels, groups) if l == label]
        class_to_group[label] = random.choice(candidates)

num_classes = len(CLASS_NAMES)
fig, axes = plt.subplots(num_classes, 5, figsize=(10, 2 * num_classes))

for row, label in enumerate(sorted(class_to_group.keys())):
    group_key = class_to_group[label]
    # Gather all images belonging to this instance, in order
    instance_paths = sorted([p for p, l, g in zip(paths, labels, groups)
                              if g == group_key])

    for col in range(5):
        ax = axes[row, col] if num_classes > 1 else axes[col]
        if col < len(instance_paths):
            img = Image.open(instance_paths[col]).convert('RGB')
            ax.imshow(img)
        ax.axis('off')
        if col == 0:
            ax.set_ylabel(CLASS_NAMES[label], fontsize=10, rotation=0, labelpad=40, va='center')
    axes[row, 0].set_title(f'{CLASS_NAMES[label]} — {group_key}', loc='left', fontsize=9)

plt.suptitle('One Instance (5 images) per Class', fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Observations:**
# - Background setting in somewhat consistent across all classes and subjects
# - Some frames of instances in different classes share very similar gestures which may confuse the model. (i.e. AllClear and NotClear)

# %% [markdown]
# ### Class distribution

# %%
groups_arr = np.array(groups)
instance_counts_per_class = {}
for class_idx, class_name in enumerate(CLASS_NAMES):
    class_mask = [c == class_idx for c in class_indices]
    class_instances = len(set(g for g, is_class in zip(groups, class_mask) if is_class))
    instance_counts_per_class[class_name] = class_instances

fig, ax = plt.subplots(figsize=(10, 4))
ax.bar(instance_counts_per_class.keys(),
       instance_counts_per_class.values(),
       color='darkorange', edgecolor='white')
ax.set_title('Unique Instance Count per Class')
ax.set_ylabel('Instance Count')
ax.set_xlabel('Class')
ax.tick_params(axis='x', labelsize=8, rotation=45)
for i, (k, v) in enumerate(instance_counts_per_class.items()):
    ax.text(i, v, str(v), ha='center', va='bottom', fontsize=8)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Observations**
#
# - *Land* has the most instances in the dataset with 122
# - Four classes have less than 65 instances, with two having less than 50 instances (*Landing Direction*, *MoveDownward*)
# - Majority of the classes has an instance count in the 80-100 range

# %% [markdown]
# ### Subject Distribution

# %%
# ---- Instance distribution per subject ----
groups_arr = np.array(groups)
subjects = np.array([g.split('_')[0] for g in groups])
instance_counts_per_subject = {}
for subject in sorted(set(subjects)):
    subject_mask = (subjects == subject)
    subject_instances = len(set(groups_arr[subject_mask]))
    instance_counts_per_subject[subject] = subject_instances

fig, ax = plt.subplots(figsize=(10, 4))
ax.bar(instance_counts_per_subject.keys(),
       instance_counts_per_subject.values(),
       color='forestgreen', edgecolor='white')
ax.set_title(f'Unique Instance Count per Subject')
ax.set_ylabel('Instance Count')
ax.set_xlabel('Subject')
ax.tick_params(axis='x', labelsize=8, rotation=45)
for i, (k, v) in enumerate(instance_counts_per_subject.items()):
    ax.text(i, v, str(v), ha='center', va='bottom', fontsize=8)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Observations**
#
# - Total of 11 subjects contributed to the dataset
# - Majority of subjects were featured in 100 or more instances
# - Four subjects (S3, S9, S14, S15) featured in fewer than 70 instances, with the difference between S3 and S5 being greater than 30 (32 instance difference)

# %% [markdown]
# ### Split dataset

# %% [markdown]
# Before data analysis, the dataset needs to be split into train, validation and test sets to avoid any data leakage. The data will be split into 70% training, and 15% each for the validation and test sets. Since there is a small amount of data available with only 1059 instances with some classes having less than 50 instances, allocating as much data as possible for training the dataset is imperative to ensure that the model is able to capture patterns within the data and generalise well against new data. Instances were used as the metric to quantify the amount of available data instead images as the main requirement of the drone model is to recognise gestures based on instances (multiple frames) rather than individual images (single frame).
#
# With the class imbalance in instance distribution, a stratified split is chosen over a random split. This is to preserve the overall class proportion of the dataset. Additionally with the total dataset being relatively small, stratified sampling can also prevent any bias as a random split can result in any of the datasets having more minority class instances compared to the other sets.
#
# The validation method used for this task is cross validation. This method was chosen as having a single hold-out validation split is too unreliable to perform and compare hyperparameter tuning and model comparison. An unlucky seed for either the training or validation set may produce results not representative of the actual performance of the model. For this project, a 5-fold stratified k-fold is performed as with (1 - test_size) / n_splits, where n_splits=0.15 equates to roughly 5 folds.
#
# Final testing will be conducted with hold-out validation.

# %%
import numpy as np
from collections import Counter
from sklearn.model_selection import StratifiedGroupKFold


def stratified_group_train_test_split(all_samples, class_indices, groups, test_size=0.15, random_state=42):
    """
    Splits off a held-out test set (instance-grouped, stratified).
    Returns the remaining train+val pool for downstream K-fold CV.
    """
    all_samples = np.array(all_samples, dtype=object)
    class_indices = np.array(class_indices)
    groups = np.array(groups)

    n_splits_1 = max(2, round(1 / test_size))
    sgkf1 = StratifiedGroupKFold(n_splits=n_splits_1, shuffle=True, random_state=random_state)
    trainval_idx, test_idx = next(sgkf1.split(all_samples, class_indices, groups))

    test_samples = [(all_samples[i][0], class_indices[i], groups[i]) for i in test_idx]

    g_trainval, g_test = set(groups[trainval_idx]), set(groups[test_idx])
    assert not (g_trainval & g_test), f"Leakage trainval/test: {g_trainval & g_test}"

    print(f"Trainval: {len(trainval_idx)} images across {len(g_trainval)} instances")
    print(f"Test:     {len(test_samples)} images across {len(g_test)} instances")

    return trainval_idx, test_idx, test_samples


def stratified_group_kfold_splits(all_samples, class_indices, groups, trainval_idx, n_splits=5, random_state=42):
    """
    Performs 5-fold stratified group CV over the trainval pool.
    Yields (fold, train_samples, val_samples, train_idx, val_idx) per fold.
    Indices returned are into the ORIGINAL all_samples/class_indices/groups arrays.
    """
    all_samples = np.array(all_samples, dtype=object)
    class_indices = np.array(class_indices)
    groups = np.array(groups)

    tv_samples = all_samples[trainval_idx]
    tv_classes = class_indices[trainval_idx]
    tv_groups = groups[trainval_idx]

    sgkf = StratifiedGroupKFold(n_splits=n_splits, shuffle=True, random_state=random_state)

    fold_splits = []

    for fold, (train_sub_idx, val_sub_idx) in enumerate(sgkf.split(tv_samples, tv_classes, tv_groups)):
        train_idx = trainval_idx[train_sub_idx]
        val_idx = trainval_idx[val_sub_idx]

        train_samples = [(all_samples[i][0], class_indices[i], groups[i]) for i in train_idx]
        val_samples   = [(all_samples[i][0], class_indices[i], groups[i]) for i in val_idx]

        # Sanity check: no group leakage between this fold's train/val
        g_train, g_val = set(groups[train_idx]), set(groups[val_idx])
        assert not (g_train & g_val), f"Leakage train/val in fold {fold}: {g_train & g_val}"

        print(f"\n=== Fold {fold + 1}/{n_splits} ===")
        print(f"Train: {len(train_samples)} images across {len(g_train)} instances")
        print(f"Val:   {len(val_samples)} images across {len(g_val)} instances")

        fold_splits.append((fold, train_samples, val_samples, train_idx, val_idx))

    return fold_splits

# %% [markdown]
# **Transform datasets for normalisation**

# %%
# ---- Configuration & Execution ----
CLASS_NAMES = [
    'AllClear', 'HaveCommand', 'Hover', 'Land', 'LandingDirection', 
    'MoveAhead', 'MoveDownward', 'MoveToLeft', 'MoveToRight', 'MoveUpward', 
    'NotClear', 'SlowDown', 'WaveOff'
]

# ---- Load dataset metadata ----
samples, class_indices, groups = load_dataset(root=DATA_DIR, class_names=CLASS_NAMES)

trainval_idx, test_idx, test_samples = stratified_group_train_test_split(
    samples, class_indices, groups, test_size=0.15, random_state=42
)

fold_splits = stratified_group_kfold_splits(
    samples, class_indices, groups, trainval_idx, n_splits=5, random_state=42
)

IMG_SIZE = 128

# Basic transforms (no augmentation yet)
train_transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
])

val_transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
])

test_dataset = stackedImageLoader(test_samples, transform=val_transform)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False, num_workers=0, pin_memory=True)

for fold, train_samples, val_samples, train_idx, val_idx in fold_splits:
    train_dataset = stackedImageLoader(train_samples, transform=train_transform)
    val_dataset   = stackedImageLoader(val_samples, transform=val_transform)

    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True,  num_workers=2, pin_memory=True)
    val_loader   = DataLoader(val_dataset,   batch_size=64, shuffle=False, num_workers=2, pin_memory=True)
    
test_loader  = DataLoader(test_dataset,  batch_size=64, shuffle=False, num_workers=2, pin_memory=True)
# Out:
# Trainval: 4535 images across 907 instances
# Test:     760 images across 152 instances
#
# === Fold 1/5 ===
# Train: 3630 images across 726 instances
# Val:   905 images across 181 instances
#
# === Fold 2/5 ===
# Train: 3625 images across 725 instances
# Val:   910 images across 182 instances
#
# === Fold 3/5 ===
# Train: 3630 images across 726 instances
# Val:   905 images across 181 instances
#
# === Fold 4/5 ===
# Train: 3625 images across 725 instances
# Val:   910 images across 182 instances
#
# === Fold 5/5 ===
# Train: 3630 images across 726 instances
# Val:   905 images across 181 instances

# %% [markdown]
# ## Defining Performance Target

# %% [markdown]
# ### Primary performance metric
# **Choice:** Macro F1 Score
#
# The macro F1 score is the unweighted average of the F1 score, a metric which is a combination of both precision and recall.
#
# Macro F1 score was chosen as the performance metric for this project is due to class imbalance present in the dataset. In skewed datasets, accuracy can be misleading especially if it is only precise in identifying majority tasks.

# %% [markdown]
# ### Performance Target
# **Target:** 0.85 Macro F1 Score
#
# **Justification:**
# Since the task requires the model to identify sequences of images rather than a single image, it is assumed that the task will be more difficult to accomplish compared to regular image classification. Additionally, the restriction of only being able to utilise a 2D CNN instead of more powerful CV models may limit the maximum performance that can be achieved.

# %% [markdown]
# ### Image information

# %%
frames, label = train_dataset[0]
print(frames.shape)
# Out:
# torch.Size([5, 3, 128, 128])

# %%
# import torch
# from torch.utils.data import DataLoader
# from torchvision import transforms

# IMG_SIZE = 128

# # Minimal transform: resize + convert to tensor, NO normalization yet
# base_transform = transforms.Compose([
#     transforms.Resize((IMG_SIZE, IMG_SIZE)),
#     transforms.ToTensor(),
# ])

# def compute_mean_std(dataset, batch_size=64, num_workers=0):
#     """
#     Computes per-channel mean and std over a dataset of 5-frame clips.
#     Assumes each sample's image tensor has shape (5, C, H, W) — adjust if different.
#     """
#     loader = DataLoader(dataset, batch_size=batch_size, shuffle=False, num_workers=num_workers)

#     channel_sum = None
#     channel_sq_sum = None
#     n_pixels = 0

#     for images, _ in loader:
#         # images shape: (B, T, C, H, W) -> flatten batch and time into one dim
#         b, t, c, h, w = images.shape
#         images = images.view(b * t, c, h, w)

#         if channel_sum is None:
#             channel_sum = torch.zeros(c)
#             channel_sq_sum = torch.zeros(c)

#         channel_sum += images.sum(dim=[0, 2, 3])
#         channel_sq_sum += (images ** 2).sum(dim=[0, 2, 3])
#         n_pixels += images.size(0) * images.size(2) * images.size(3)

#     mean = channel_sum / n_pixels
#     std = torch.sqrt(channel_sq_sum / n_pixels - mean ** 2)
#     return mean, std


# # ---- Compute mean/std per fold ----
# fold_stats = []

# for fold, train_samples, val_samples, train_idx, val_idx in fold_splits:
#     raw_train_dataset = stackedImageLoader(train_samples, transform=base_transform)
#     mean, std = compute_mean_std(raw_train_dataset)

#     print(f"Fold {fold + 1} — mean: {mean.tolist()}, std: {std.tolist()}")
#     fold_stats.append({'fold': fold + 1, 'mean': mean.tolist(), 'std': std.tolist()})

# %%
# import pandas as pd

# rows = []
# for stat in fold_stats:
#     row = {'fold': stat['fold']}
#     for i, (m, s) in enumerate(zip(stat['mean'], stat['std'])):
#         row[f'mean_ch{i}'] = round(m, 4)
#         row[f'std_ch{i}'] = round(s, 4)
#     rows.append(row)

# fold_stats_df = pd.DataFrame(rows).set_index('fold')
# fold_stats_df

# %% [markdown]
# ## Baseline Model

# %% [markdown]
# **Model Choice:** MobileNetsV2 with Transfer Learning using ImageNets
#
# **Justification:** The model architecture for this project is restricted to a 2-D CNN as it to be deployed onto a drone. MobileNetsV2 is known to be computationally efficient unlike ResNet. In addition, the choice for transfer learning with the ImageNets dataset is attributed to the size of the dataset, having only around 727 images after stacking images to form instances.
#
# **Additional information about the model:**
# - Learning rate = 0.001 (1e-3)
# - Optimizer = None
# - Augmentation = None
# - Regularisation = None
# - Images normalised to ImageNets mean and std to match network distribution
# - Images resized to 224 x 224 to accomodate MobileNetsV2
#
# *Code is based on the Lecture 6 Notebook*

# %% [markdown]
# ### Pre-processing

# %%
# ---- Configuration & Execution ----
CLASS_NAMES = [
    'AllClear', 'HaveCommand', 'Hover', 'Land', 'LandingDirection', 
    'MoveAhead', 'MoveDownward', 'MoveToLeft', 'MoveToRight', 'MoveUpward', 
    'NotClear', 'SlowDown', 'WaveOff'
]

IMAGENET_MEAN = [0.485, 0.456, 0.406]
IMAGENET_STD  = [0.229, 0.224, 0.225]

# Change image size to accomodate MobileNetsV2
IMG_SIZE = 224

# Basic transforms (no augmentation yet)
train_transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(IMAGENET_MEAN, IMAGENET_STD),
])

val_transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(IMAGENET_MEAN, IMAGENET_STD),
])

# %% [markdown]
# ### Set up instrumentation

# %%
from itertools import cycle

def plotter(history_hold, metric='loss', ylim=None):
    cycol = cycle('bgrcmk')
    for name, hist in history_hold.items():
        y_train = hist[metric]
        y_val   = hist['val_' + metric]
        x = np.arange(len(y_val))
        c = next(cycol)
        plt.plot(x, y_train, c + '-',  label=name + '_train')
        plt.plot(x, y_val,   c + '--', label=name + '_val')
    plt.legend()
    plt.xlim([1, max(plt.xlim())])
    if ylim is not None:
        plt.ylim(ylim)
    plt.xlabel('Epoch')
    plt.ylabel(metric)
    plt.grid(True)

m_histories = {}

# %%
from sklearn.metrics import (accuracy_score, precision_score, recall_score,
                              roc_auc_score, f1_score)

def run_epoch(model, loader, criterion, optimizer=None, num_classes=13):
    training = optimizer is not None
    model.train(training)
    total_loss, ys, preds, all_probs = 0.0, [], [], []
    ctx = torch.enable_grad() if training else torch.no_grad()
    with ctx:
        for xb, yb in loader:
            xb, yb = xb.to(device), yb.to(device)
            logits = model(xb)
            loss = criterion(logits, yb)
            if training:
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
            total_loss += loss.item() * len(xb)
            probs = torch.softmax(logits, dim=1).detach().cpu().numpy()
            ys.extend(yb.cpu().numpy())
            preds.extend(logits.argmax(1).detach().cpu().numpy())
            all_probs.extend(probs)
    n = len(ys)
    all_probs = np.array(all_probs)
    metrics = {
        'loss':      total_loss / n,
        'f1_score':  f1_score(ys, preds, average='macro'),
        'accuracy':  accuracy_score(ys, preds),
        'precision': precision_score(ys, preds, average='macro', zero_division=0),
        'recall':    recall_score(ys, preds, average='macro', zero_division=0),
        'auc':       roc_auc_score(ys, all_probs, multi_class='ovr', average='macro')
                     if len(set(ys)) > 1 else float('nan'),
    }
    return metrics


def train_and_track(model, train_loader, val_loader, epochs=10, lr=1e-3,
                    optimizer=None, criterion=None, verbose=True):
    model = model.to(device)
    if optimizer is None:
        optimizer = torch.optim.Adam(
            filter(lambda p: p.requires_grad, model.parameters()), lr=lr)
    if criterion is None:
        criterion = nn.CrossEntropyLoss()  # fallback if no weighted criterion is passed

    hist = {k: [] for k in ['loss', 'f1_score', 'accuracy', 'precision', 'recall', 'auc',
                             'val_loss', 'val_f1_score', 'val_accuracy', 'val_precision', 'val_recall', 'val_auc']}
    for ep in range(epochs):
        tr = run_epoch(model, train_loader, criterion, optimizer=optimizer)
        vl = run_epoch(model, val_loader,   criterion, optimizer=None)
        for k, v in tr.items():        hist[k].append(v)
        for k, v in vl.items():        hist['val_' + k].append(v)
        if verbose:
            print(f'ep {ep+1:2d}/{epochs}  '
                  f'loss {tr["loss"]:.3f}  f1 {tr["f1_score"]:.3f}  acc {tr["accuracy"]:.3f}  |  '
                  f'val_loss {vl["loss"]:.3f}  val_f1 {vl["f1_score"]:.3f}  val_acc {vl["accuracy"]:.3f}  '
                  f'val_prec {vl["precision"]:.3f}  val_rec {vl["recall"]:.3f}  val_auc {vl["auc"]:.3f}')
    return hist

# %% [markdown]
# ### Perform Early Fusion

# %% [markdown]
# One of the main requirements for this project is to process an entire instance to classify a gesture instead of individual frames. This is accomplished by performing data fusion, which is the '[combination of] data from multiple sources to produce more accurate, complete, and actionable insights than those derived from individual datasets' (GeeksForGeeks, 2025). Two types of data fusion is early and late fusion.
#
# Early fusion involves the combination of multiple data sources (i.e. multiple images apart of an instance) at the feature level before processed through the model (GeeksForGeeks, 2025).
# Late fusion involves training individual models seperately and combining their predictions at a later stage (GeeksForGeeks, 2025).
#
# For this development pipeline, early fusion is preferred over late fusion. Since the model needs to identify motion-based gestures, the temporal order of the five input frames need to be maintained. Late fusion processes each frame independently and derives an average or most confident prediction out of the frames, removing any temporal information. This means that the model can classify gestures even when gestures are performed out of order or reversed. Early fusion addresses this by sequentially stacking 5 consecutive frames together, changing the image shape from (224,224,3) to (224,224,15); with each frame at a distinct position on the channel. This preserves the temporal information of the instance that the model can train from.
#
# With the change in image shape, this means that the first convolutional layer has to be modified to accept the image size. This modification also restricts the use of any ImageNets weights for the first layer, requiring the layer to be trained from scratch using the stacked images.
#
# https://cs231n.stanford.edu/2024/slides/2024/lecture_10.pdf

# %%
class EarlyFusionMobileNet(nn.Module):
    def __init__(self, num_classes, num_frames=5, freeze_base=True, dropout=0.0):
        super().__init__()
        base = mobilenet_v2(weights=MobileNet_V2_Weights.IMAGENET1K_V2)

        # Replace the first conv layer: 3 input channels -> num_frames * 3
        old_conv = base.features[0][0]  # Conv2d(3, 32, kernel_size=3, stride=2, ...)
        new_conv = nn.Conv2d(
            in_channels=3 * num_frames,
            out_channels=old_conv.out_channels,
            kernel_size=old_conv.kernel_size,
            stride=old_conv.stride,
            padding=old_conv.padding,
            bias=(old_conv.bias is not None),
        )

        # Initialize new conv by REPLICATING pretrained weights across the frame dimension,
        # scaled down - preserves useful ImageNet-learned edge/texture filters instead of
        # starting this layer from random noise.
        with torch.no_grad():
            new_conv.weight[:] = old_conv.weight.repeat(1, num_frames, 1, 1) / num_frames
            if old_conv.bias is not None:
                new_conv.bias[:] = old_conv.bias

        base.features[0][0] = new_conv

        if freeze_base:
            for name, p in base.features.named_parameters():
                if '0.0' not in name:  # keep the new first conv layer trainable
                    p.requires_grad = False

        base.classifier = nn.Sequential(
            nn.Dropout(dropout),
            nn.Linear(1280, num_classes),
        )

        self.backbone = base
        self.num_frames = num_frames

    def forward(self, x):
        # x: (B, T, C, H, W) -> concatenate frames along channel dim
        b, t, c, h, w = x.shape
        x = x.view(b, t * c, h, w)  # (B, 15, H, W)
        return self.backbone(x)

# %%
from torchvision.models import mobilenet_v2, MobileNet_V2_Weights

def build_tfl_model(freeze_base=True, dropout=0.0, num_classes=13):
    return EarlyFusionMobileNet(num_classes=num_classes, freeze_base=freeze_base,
                                dropout=dropout)

# %%
def plot_avg_across_folds(m_histories, metric='loss', epochs=10):
    """
    Averages a metric (train and val) across all fold histories in m_histories,
    and plots mean ± std band per epoch.
    """
    train_key = metric
    val_key = 'val_' + metric

    train_curves = np.array([hist[train_key] for hist in m_histories.values()])  # (n_folds, epochs)
    val_curves   = np.array([hist[val_key]   for hist in m_histories.values()])

    train_mean, train_std = train_curves.mean(axis=0), train_curves.std(axis=0)
    val_mean,   val_std   = val_curves.mean(axis=0),   val_curves.std(axis=0)

    x = np.arange(1, epochs + 1)

    plt.figure(figsize=(8, 5))
    plt.plot(x, train_mean, 'b-', label='train (mean)')
    plt.fill_between(x, train_mean - train_std, train_mean + train_std, color='b', alpha=0.15)

    plt.plot(x, val_mean, 'r--', label='val (mean)')
    plt.fill_between(x, val_mean - val_std, val_mean + val_std, color='r', alpha=0.15)

    plt.xlabel('Epoch')
    plt.ylabel(metric)
    plt.title(f'Average {metric} across {len(m_histories)} folds (± std)')
    plt.legend()
    plt.grid(True)
    plt.show()

    print(f"Final epoch — train {metric}: {train_mean[-1]:.4f} ± {train_std[-1]:.4f}  |  "
          f"val {metric}: {val_mean[-1]:.4f} ± {val_std[-1]:.4f}")

# %%
from sklearn.utils.class_weight import compute_class_weight

m_baseline = {}
class_indices_arr = np.array(class_indices)

for fold, train_samples, val_samples, train_idx, val_idx in fold_splits:
    print(f"========== Fold {fold + 1} ==========")
    torch.manual_seed(42)
    train_dataset = stackedImageLoader(train_samples, transform=train_transform)
    val_dataset   = stackedImageLoader(val_samples, transform=val_transform)
    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True,  num_workers=0, pin_memory=True)
    val_loader   = DataLoader(val_dataset,   batch_size=64, shuffle=False, num_workers=0, pin_memory=True)

    # Fresh model each fold
    model_tfl = build_tfl_model(freeze_base=True, dropout=0.0, num_classes=len(CLASS_NAMES))

    # Compute class weights for this fold
    fold_train_targets = class_indices_arr[train_idx]
    class_weights = compute_class_weight(
        class_weight='balanced',
        classes=np.arange(len(CLASS_NAMES)),
        y=fold_train_targets
    )
    class_weights_tensor = torch.tensor(class_weights, dtype=torch.float32).to(device)
    criterion = nn.CrossEntropyLoss(weight=class_weights_tensor)

    fold_key = f'Model_tfl_fold{fold + 1}'

    # Train head
    m_baseline[fold_key] = train_and_track(
        model_tfl, train_loader, val_loader,
        epochs=10, lr=1e-3,
        criterion=criterion
    )
# Out:
# ========== Fold 1 ==========
# ep  1/10  loss 2.281  f1 0.257  acc 0.291  |  val_loss 1.797  val_f1 0.331  val_acc 0.429  val_prec 0.327  val_rec 0.387  val_auc 0.894
# ep  2/10  loss 1.275  f1 0.616  acc 0.631  |  val_loss 0.964  val_f1 0.566  val_acc 0.632  val_prec 0.714  val_rec 0.593  val_auc 0.963
# ep  3/10  loss 0.558  f1 0.883  acc 0.873  |  val_loss 0.660  val_f1 0.695  val_acc 0.720  val_prec 0.737  val_rec 0.696  val_auc 0.977
# ep  4/10  loss 0.226  f1 0.963  acc 0.960  |  val_loss 0.574  val_f1 0.787  val_acc 0.808  val_prec 0.835  val_rec 0.801  val_auc 0.981
# ep  5/10  loss 0.104  f1 0.974  acc 0.974  |  val_loss 0.501  val_f1 0.801  val_acc 0.808  val_prec 0.828  val_rec 0.809  val_auc 0.984
# ep  6/10  loss 0.076  f1 0.979  acc 0.978  |  val_loss 0.508  val_f1 0.805  val_acc 0.819  val_prec 0.828  val_rec 0.812  val_auc 0.984
# ep  7/10  loss 0.038  f1 0.996  acc 0.996  |  val_loss 0.515  val_f1 0.799  val_acc 0.808  val_prec 0.819  val_rec 0.807  val_auc 0.984
# ...

# %%
# ---- Plot average loss and F1 across all 5 folds ----
plot_avg_across_folds(m_baseline, metric='loss', epochs=10)
plot_avg_across_folds(m_baseline, metric='f1_score',   epochs=10)

# Store results
all_results = {}
all_results['v1 (baseline)'] = m_baseline
# Out:
# Final epoch — train loss: 0.0171 ± 0.0103  |  val loss: 0.4019 ± 0.0824
# Final epoch — train f1_score: 0.9977 ± 0.0028  |  val f1_score: 0.8672 ± 0.0238

# %% [markdown]
# **Observations:**
# - Baseline model surpasses the target F1 score of 0.80 with a validation F1 score average of 0.86 across five folds.
# - However the model is overfitting with the gap between the training and validation loss, with the validation loss double the training loss.
# - Validation loss stops improving around epochs=3
#
# Since the baseline is able to exceed the target metric set, we will use the baseline model with transfer learning as a basis, and perform tuning on specific hyperparameters to maximise the target metric while reducing overfitting.

# %% [markdown]
# ## Hyperparameter Tuning

# %% [markdown]
# While the target metric is met, a major issue with the baseline model is overfitting. This indicates that the model is memorising the dataset rather than learning patterns in the dataset. This can be prevented by tuning various parameters which are suspected of causing overfitting. This includes:
# - Data augmentation
# - Learning rate
# - Dropout and weight regularisation
# - Fine tuning
#
# Due to time constraints, hyperparemeter tuning will only be performed on the first fold of cross validation - essentially performing hold-out validation.

# %% [markdown]
# ### Data Augmentation

# %% [markdown]
# To improve the generalisation performance of the model, augmentation is performed on the existing images in the train dataset. Augmentation provides additional variability and diversity towards the dataset, which is especially crucial as the amount of instances contained in the dataset is relatively small.
#
# Augmentations of different strengths are experimented on. Light augmentation involves the rotation of images, whereas strong augmentation involves some colour space (i.e. brightness and contrast) and geometric transformations (rotation, zoom). Aggressive augmentations, such as horizontal flipping and extreme rotations will not be performed on the data as many of the gestures are dependent on a position of specific features (i.e. arms up, arms to the left/right, etc).
#
# Since our model is designed to utilise all frames within an instance, we must also perform identical transformations for all frames belonging to the same instance. If each frame within an instance is tranformed individually (random degree of rotation in any direction), then the resulting frame is no longer spatially aligned. This can confuse the model in identifying motion or held poses, making it difficult for the model to recognise any patterns. SynchronizedClipTransform addresses this issue by sampling augmentation per instance, and applying the identical augmentations onto all frames within the instance, preserving spatial information.

# %%
# Derived from DL week 6 lab notebook
def plot_experiments(results, show_train=True, show_val=True):
    fig, axes = plt.subplots(1, 2, figsize=(14, 5))
    for name, hist in results.items():
        epochs = range(1, len(hist['loss']) + 1)
        if show_train:
            axes[0].plot(epochs, hist['loss'], label=f'{name} (Train)', marker='o', markersize=3)
            axes[1].plot(epochs, hist['f1_score'], label=f'{name} (Train)', marker='o', markersize=3)
        if show_val:
            axes[0].plot(epochs, hist['val_loss'], label=f'{name} (Val)', linestyle='--', marker='x', markersize=3)
            axes[1].plot(epochs, hist['val_f1_score'], label=f'{name} (Val)', linestyle='--', marker='x', markersize=3)
    for ax, ylabel in zip(axes, ['Loss', 'F1 Score']):
        ax.set_xlabel('Epoch'); ax.set_ylabel(ylabel); ax.set_title(ylabel)
        ax.legend(fontsize=8); ax.grid(True, linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()

# %%
def plot_single_fold(hist, metric='loss', epochs=10):
    """
    Plots train vs val curves for a single fold (no averaging across folds).
    fold_key: the key identifying which fold's history to plot, e.g. 'fold1'
              or 'Model_tfl_fold1', matching however m_histories is keyed.
    """
    train_key = metric
    val_key = 'val_' + metric

    train_curve = np.array(hist[train_key])
    val_curve   = np.array(hist[val_key])
    x = np.arange(1, epochs + 1)

    plt.figure(figsize=(8, 5))
    plt.plot(x, train_curve, 'b-',  label='train')
    plt.plot(x, val_curve,   'r--', label='val')
    plt.xlabel('Epoch')
    plt.ylabel(metric)
    plt.title(f'{metric} - Single Fold')
    plt.legend()
    plt.grid(True)
    plt.show()

    print(f"Final epoch — train {metric}: {train_curve[-1]:.4f}  |  "
          f"val {metric}: {val_curve[-1]:.4f}")

# %%
# ---- Configuration & Execution ----
CLASS_NAMES = [
    'AllClear', 'HaveCommand', 'Hover', 'Land', 'LandingDirection', 
    'MoveAhead', 'MoveDownward', 'MoveToLeft', 'MoveToRight', 'MoveUpward', 
    'NotClear', 'SlowDown', 'WaveOff'
]

IMAGENET_MEAN = [0.485, 0.456, 0.406]
IMAGENET_STD  = [0.229, 0.224, 0.225]

# Change image size to accomodate MobileNetsV2
IMG_SIZE = 224

# # Augmentation Levels
# aug_configs = {
#     # Light Augmentation - 10 degree rotation
#     'Light Aug': transforms.Compose([
#         transforms.Resize((IMG_SIZE, IMG_SIZE)),
#         transforms.RandomRotation(degrees=10),
#         transforms.ToTensor(),
#         transforms.Normalize(IMAGENET_MEAN, IMAGENET_STD),
#     ]),
#     # Strong Augmentation - 10 degree rotation, zoom, brightness, contrast
#     'Strong Aug': transforms.Compose([
#         transforms.Resize((IMG_SIZE, IMG_SIZE)),
#         transforms.RandomRotation(degrees=10),
#         # zoom : Scales image between 80% and 120% of its size, then crops back to 224x224
#         transforms.RandomResizedCrop(size=(224, 224), scale=(0.8, 1.2)),
#         # brightness: 0.2 means randomly choosing a factor between [0.8, 1.2]
#         # contrast: 0.2 means randomly choosing a factor between [0.8, 1.2]
#         transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0, hue=0),
#         transforms.ToTensor(),
#         transforms.Normalize(IMAGENET_MEAN, IMAGENET_STD),
#     ]),
# }

# Synchronise the transforms used for each frame so all images within the frames share identical augmentations
import random
import torchvision.transforms.functional as TF

class SynchronizedClipTransform:
    def __init__(self, img_size, level='none'):
        self.img_size = img_size
        self.level = level  # 'light', 'strong'

    def __call__(self, frames):  # list of 5 PIL images
        angle = random.uniform(-10, 10)
        frames = [TF.rotate(f, angle) for f in frames]

        if self.level == 'strong':
            # Same crop box and color params applied to every frame
            scale = random.uniform(0.8, 1.0)
            i, j, h, w = transforms.RandomResizedCrop.get_params(
                frames[0], scale=(scale, 1.0), ratio=(1.0, 1.0)
            )
            frames = [TF.resized_crop(f, i, j, h, w, (self.img_size, self.img_size)) for f in frames]

            brightness = random.uniform(0.8, 1.2)
            contrast = random.uniform(0.8, 1.2)
            frames = [TF.adjust_brightness(f, brightness) for f in frames]
            frames = [TF.adjust_contrast(f, contrast) for f in frames]

        frames = [TF.resize(f, (self.img_size, self.img_size)) for f in frames]
        frames = [TF.to_tensor(f) for f in frames]
        frames = [TF.normalize(f, IMAGENET_MEAN, IMAGENET_STD) for f in frames]
        return torch.stack(frames)


aug_configs = {
    'Light Aug': SynchronizedClipTransform(IMG_SIZE, level='light'),
    'Strong Aug': SynchronizedClipTransform(IMG_SIZE, level='strong'),
}

val_transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(IMAGENET_MEAN, IMAGENET_STD),
])

# %%
class_indices_arr = np.array(class_indices)
aug_results = {}

# ---- Take only fold 0 ----
fold, train_samples, val_samples, train_idx, val_idx = fold_splits[0]
for aug_name, aug_transform in aug_configs.items():
    print(f"========== Augmentation = {aug_name} ==========")
    torch.manual_seed(42)
    train_dataset_aug = stackedImageLoader(train_samples, transform=aug_transform, synchronized=True)
    val_dataset       = stackedImageLoader(val_samples, transform=val_transform)
    
    train_loader = DataLoader(train_dataset_aug, batch_size=32, shuffle=True,  num_workers=0, pin_memory=True)
    val_loader   = DataLoader(val_dataset,       batch_size=64, shuffle=False, num_workers=0, pin_memory=True)
    
    # Fresh model
    model_tfl = build_tfl_model(freeze_base=True, dropout=0.0, num_classes=len(CLASS_NAMES))
    
    # Class weights, computed from fold 0's train labels only
    fold_train_targets = class_indices_arr[train_idx]
    class_weights = compute_class_weight(
        class_weight='balanced',
        classes=np.arange(len(CLASS_NAMES)),
        y=fold_train_targets
    )
    class_weights_tensor = torch.tensor(class_weights, dtype=torch.float32).to(device)
    criterion = nn.CrossEntropyLoss(weight=class_weights_tensor)
    
    # Train
    aug_results[aug_name] = train_and_track(
        model_tfl, train_loader, val_loader,
        epochs=10, lr=1e-3,
        criterion=criterion
    )
# Out:
# ========== Augmentation = Light Aug ==========
# ep  1/10  loss 2.298  f1 0.237  acc 0.277  |  val_loss 1.782  val_f1 0.335  val_acc 0.412  val_prec 0.330  val_rec 0.407  val_auc 0.894
# ep  2/10  loss 1.361  f1 0.538  acc 0.566  |  val_loss 0.988  val_f1 0.568  val_acc 0.632  val_prec 0.633  val_rec 0.602  val_auc 0.955
# ep  3/10  loss 0.694  f1 0.798  acc 0.787  |  val_loss 0.666  val_f1 0.657  val_acc 0.681  val_prec 0.688  val_rec 0.660  val_auc 0.970
# ep  4/10  loss 0.387  f1 0.878  acc 0.875  |  val_loss 0.517  val_f1 0.769  val_acc 0.791  val_prec 0.801  val_rec 0.775  val_auc 0.985
# ep  5/10  loss 0.238  f1 0.927  acc 0.928  |  val_loss 0.441  val_f1 0.819  val_acc 0.835  val_prec 0.856  val_rec 0.823  val_auc 0.991
# ep  6/10  loss 0.149  f1 0.954  acc 0.953  |  val_loss 0.402  val_f1 0.834  val_acc 0.830  val_prec 0.854  val_rec 0.840  val_auc 0.990
# ...

# %%
plot_experiments(aug_results)

# Select the best augmentation and record it
best_aug_name = max(aug_results, key=lambda k: max(aug_results[k]['val_f1_score']))
print(f'Best augmentation: {best_aug_name}')
best_aug_transform = aug_configs[best_aug_name]

# Store in all_results
all_results['v2: +Aug'] = aug_results[best_aug_name]
# Out:
# Best augmentation: Strong Aug

# %% [markdown]
# **Observations:**
# - The validation f1 score of strong augmentation is higher than light augmentation's f1 score - can be attributed to improved generalization ability from more diverse data
# - Validation loss from both augmentation configurations are significantly lower than the baseline's validation loss, around 33% less
#     - weak aug: 0.430 loss after 10 epochs
#     - strong aug: 0.296 loss after 10 epochs
# - Signs of overfitting still present in both augmentation models, with relatively large gaps between train and validation f1 scores.
# - Train and validation f1 score gap is halved in the strong augmentation model when compared to the baseline model (0.964 train vs 0.899 val at ep=8 for strong aug (0.065 gap))
#
# After experimentation, strong augmentation is selected over light augmentation. This is due to higher overall validation performance (higher f1 score), as well as having a lower loss value after training indicating that the strong aug model overfits less. However, there is still overfitting present in the model with the large gap between target and validation f1 scores and therefore tuning in other hyperparameters is required.

# %% [markdown]
# ### Learning Rate

# %% [markdown]
# The learning rates which are experimented for hyperparameter tuning are:
# - 0.01
# - 0.005
# - 0.001
# - 0.0005
# - 0.0001
#
# These learning rates are specifically selected as this gives a somewhat wide range to experiment while allowing for precise tuning. The aim for this section is to find the learning rate which can give the highest f1 score while avoiding any overfitting. The best-performing augmentation configuration (Found in *Data Augmentation* of Hyperparameter Tuning) will also be used for this experiment to maximise the possible f1 score.

# %%
learning_rates = [1e-2, 5e-3, 1e-3, 5e-4, 1e-4]

class_indices_arr = np.array(class_indices)

lr_results = {}

# Take only fold 0
fold, train_samples, val_samples, train_idx, val_idx = fold_splits[0]

for lr in learning_rates:
    print(f"========== Learning rate = {lr} ==========")
    torch.manual_seed(42)
    train_dataset_lr = stackedImageLoader(train_samples, transform=best_aug_transform, synchronized=True)
    val_dataset      = stackedImageLoader(val_samples, transform=val_transform)
    
    train_loader = DataLoader(train_dataset_lr, batch_size=32, shuffle=True,  num_workers=0, pin_memory=True)
    val_loader   = DataLoader(val_dataset,       batch_size=64, shuffle=False, num_workers=0, pin_memory=True)
    
    # Fresh model
    model_tfl = build_tfl_model(freeze_base=True, dropout=0.0, num_classes=len(CLASS_NAMES))
    
    # Class weights, computed from fold 0's train labels only
    fold_train_targets = class_indices_arr[train_idx]
    class_weights = compute_class_weight(
        class_weight='balanced',
        classes=np.arange(len(CLASS_NAMES)),
        y=fold_train_targets
    )
    class_weights_tensor = torch.tensor(class_weights, dtype=torch.float32).to(device)
    criterion = nn.CrossEntropyLoss(weight=class_weights_tensor)
    
    # Train
    lr_results[f'lr={lr}'] = train_and_track(
        model_tfl, train_loader, val_loader,
        epochs=10, lr=lr,
        criterion=criterion
    )
# Out:
# ========== Learning rate = 0.01 ==========
# ep  1/10  loss 2.196  f1 0.232  acc 0.262  |  val_loss 2.757  val_f1 0.163  val_acc 0.247  val_prec 0.196  val_rec 0.235  val_auc 0.796
# ep  2/10  loss 1.319  f1 0.467  acc 0.482  |  val_loss 1.522  val_f1 0.368  val_acc 0.423  val_prec 0.435  val_rec 0.445  val_auc 0.912
# ep  3/10  loss 0.955  f1 0.597  acc 0.603  |  val_loss 1.316  val_f1 0.452  val_acc 0.495  val_prec 0.541  val_rec 0.502  val_auc 0.940
# ep  4/10  loss 0.794  f1 0.679  acc 0.678  |  val_loss 0.791  val_f1 0.575  val_acc 0.687  val_prec 0.545  val_rec 0.635  val_auc 0.972
# ep  5/10  loss 0.545  f1 0.778  acc 0.770  |  val_loss 0.586  val_f1 0.712  val_acc 0.758  val_prec 0.763  val_rec 0.719  val_auc 0.978
# ep  6/10  loss 0.509  f1 0.805  acc 0.796  |  val_loss 0.666  val_f1 0.702  val_acc 0.753  val_prec 0.739  val_rec 0.736  val_auc 0.981
# ...

# %%
# Plot learning rates
plot_experiments(lr_results, show_train=False)

# Select the best lr and record it
best_lr_name = max(lr_results, key=lambda k: max(lr_results[k]['val_f1_score']))
print(f'Best lr: {best_lr_name}')

best_lr = float(best_lr_name.split('=')[1])

# Store in all_results
all_results['v2: +Aug+Lr'] = lr_results[best_lr_name]
# Out:
# Best lr: lr=0.001

# %% [markdown]
# **Observations**
# - Lower learning rates converge too slow, resulting in higher loss and lower f1 score. This is especially seen with lr=0.0001.
# - Higher learning rates result in unstable loss curves
# - lr=0.001 yields the highest validation f1 score out of all learning rates with 0.893 at ep=8.
# - Half the models reach their peak performance before ep=10 is reached - can be attributed to the model memorising the model instead of learning patterns.
#
# lr=0.001 is selected as the learning rate as it produced the highest validation f1 score. There is still overfitting present across all learning rates.

# %% [markdown]
# ### Weight Regularisation

# %% [markdown]
# Since the model still overfits, either drop-out and/or weight regularisation must be tuned so that the model properly fits. Considering that the gap between the train and validation f1 scores are still large and that the dataset is imbalanced, (l2) weight regularisation is more suited for reducing the overfitting of the model.
#
# In dropout, random neurons in the model are dropped during training (ML4Devs, 2026). While this is effective for balanced datasets, as we explored that the dataset provided for the project has several underrepresented classes (LandingDirection, MoveDownwards), the very few neurons formed from these classes are at a high risk of being dropped. With weight regularisation, larger weights are penalised more (i.e. overrepresented classes) while smaller ones remain intact.
#
# If the model still overfits despite weight regularisation, dropout can be used as a final resort to help the model in fitting. Additionally, redesigning components within the model training pipeline may be required.

# %%
weight_decays = [0.0, 1e-4, 1e-3, 1e-2]

class_indices_arr = np.array(class_indices)

wd_results = {}

# Take only fold 0
fold, train_samples, val_samples, train_idx, val_idx = fold_splits[0]

for wd in weight_decays:
    print(f"========== Weight Decay = {wd} ==========")
    torch.manual_seed(42)
    train_dataset_wd = stackedImageLoader(train_samples, transform=best_aug_transform, synchronized=True)
    val_dataset      = stackedImageLoader(val_samples, transform=val_transform)
    
    train_loader = DataLoader(train_dataset_wd, batch_size=32, shuffle=True,  num_workers=0, pin_memory=True)
    val_loader   = DataLoader(val_dataset,       batch_size=64, shuffle=False, num_workers=0, pin_memory=True)
    
    # Fresh model
    model_tfl = build_tfl_model(freeze_base=True, dropout=0.0, num_classes=len(CLASS_NAMES))

    # Define optimiser
    optimizer = torch.optim.Adam(
        filter(lambda p: p.requires_grad, model_tfl.parameters()), 
        lr=best_lr, 
        weight_decay=wd
    )
    
    # Class weights, computed from fold 0's train labels only
    fold_train_targets = class_indices_arr[train_idx]
    class_weights = compute_class_weight(
        class_weight='balanced',
        classes=np.arange(len(CLASS_NAMES)),
        y=fold_train_targets
    )
    class_weights_tensor = torch.tensor(class_weights, dtype=torch.float32).to(device)
    criterion = nn.CrossEntropyLoss(weight=class_weights_tensor)
    
    # Train
    wd_results[f'wd={wd}'] = train_and_track(
        model_tfl, train_loader, val_loader,
        epochs=10, lr=best_lr,
        criterion=criterion,
        optimizer=optimizer
    )
# Out:
# ========== Weight Decay = 0.0 ==========
# ep  1/10  loss 2.303  f1 0.249  acc 0.288  |  val_loss 1.719  val_f1 0.347  val_acc 0.434  val_prec 0.317  val_rec 0.414  val_auc 0.902
# ep  2/10  loss 1.390  f1 0.509  acc 0.530  |  val_loss 1.022  val_f1 0.552  val_acc 0.582  val_prec 0.653  val_rec 0.581  val_auc 0.954
# ep  3/10  loss 0.765  f1 0.758  acc 0.753  |  val_loss 0.632  val_f1 0.720  val_acc 0.731  val_prec 0.746  val_rec 0.736  val_auc 0.976
# ep  4/10  loss 0.484  f1 0.844  acc 0.839  |  val_loss 0.490  val_f1 0.746  val_acc 0.769  val_prec 0.733  val_rec 0.780  val_auc 0.987
# ep  5/10  loss 0.354  f1 0.857  acc 0.850  |  val_loss 0.450  val_f1 0.841  val_acc 0.841  val_prec 0.865  val_rec 0.850  val_auc 0.987
# ep  6/10  loss 0.267  f1 0.907  acc 0.905  |  val_loss 0.366  val_f1 0.819  val_acc 0.835  val_prec 0.839  val_rec 0.831  val_auc 0.991
# ...

# %%
# Plot wd
plot_experiments(wd_results, show_train=False)

# Select the best wd and record it
best_wd_name = max(wd_results, key=lambda k: max(wd_results[k]['val_f1_score']))
print(f'Best wd: {best_wd_name}')

best_wd = float(best_wd_name.split('=')[1])

# Store in all_results
all_results['v3: +Aug+Lr+Wd'] = wd_results[best_wd_name]
# Out:
# Best wd: wd=0.0001

# %% [markdown]
# **Observations:**
# - wd=0.0001 records the highest validation f1 score with 0.905 at ep=7.
#     - The difference between the train (0.939) and validation f1 score for wd=0.0001 is 0.034, 75% less than wd=0 (no weight regularisation).
# - The performance of wd=0.0001 and wd=0.01 peaks at ep=7, and then stagnates caused by the model over-memorising the training data. This is an indication that early stopping during training may be needed to preserve peformance.
# - Even with extreme weight decay (wd=0.01), the model still overfits. This can be explained by the design of the model pipeline, where the wd is only applied to a single layer as the other layers are frozen.
#     - High weight decay may have also shrunk the minority class weights to zero.

# %% [markdown]
# ## Fine Tuning

# %% [markdown]
# In the previous hyperparameter tuning experiments, only the head of the model was trained with the ImageNet weights frozen. While this is suitable for most models, the best model derived from experimentation still shown signs of overfitting. Fine tuning involves unfreezing the top few layers of the model and trains them alongside the head to adapt to the classification task. By fine tuning this model, this allows for weight decay to be applied to other layers of the model, as discussed in the weight regularisation experiment which can reduce overfitting.
# For this implementation, the learning rate derived is divided by 10 as we want to perform minor adjustments to the class weights instead of relearning them entirely. Weight decay value stays the same.
#
# In addition to fine tuning, the *train_and_track()* function is also modified to include early stoppage during model training. It was previously mentioned that many of the models tested reached peak performance before all epochs were iterated. In this function, the lowest validation loss is recorded, and training stops early if no improvement is observed within the following three epochs.

# %%
import copy

def train_and_track(model, train_loader, val_loader, epochs=10, lr=1e-3,
                    optimizer=None, criterion=None, verbose=True,
                    early_stopping=True, patience=3, restore_best=True):
    model = model.to(device)
    if optimizer is None:
        optimizer = torch.optim.Adam(
            filter(lambda p: p.requires_grad, model.parameters()), lr=lr)
    if criterion is None:
        criterion = nn.CrossEntropyLoss()

    hist = {k: [] for k in ['loss', 'f1_score', 'accuracy', 'precision', 'recall', 'auc',
                             'val_loss', 'val_f1_score', 'val_accuracy', 'val_precision', 'val_recall', 'val_auc']}

    best_val_loss = float('inf')
    best_state = None
    patience_counter = 0
    stopped_epoch = epochs  # tracks actual epoch count if stopped early

    for ep in range(epochs):
        tr = run_epoch(model, train_loader, criterion, optimizer=optimizer)
        vl = run_epoch(model, val_loader,   criterion, optimizer=None)
        for k, v in tr.items():        hist[k].append(v)
        for k, v in vl.items():        hist['val_' + k].append(v)

        if verbose:
            print(f'ep {ep+1:2d}/{epochs}  '
                  f'loss {tr["loss"]:.3f}  f1 {tr["f1_score"]:.3f}  acc {tr["accuracy"]:.3f}  |  '
                  f'val_loss {vl["loss"]:.3f}  val_f1 {vl["f1_score"]:.3f}  val_acc {vl["accuracy"]:.3f}  '
                  f'val_prec {vl["precision"]:.3f}  val_rec {vl["recall"]:.3f}  val_auc {vl["auc"]:.3f}')

        if early_stopping:
            if vl['loss'] < best_val_loss:
                best_val_loss = vl['loss']
                patience_counter = 0
                if restore_best:
                    best_state = copy.deepcopy(model.state_dict())
            else:
                patience_counter += 1
                if patience_counter >= patience:
                    if verbose:
                        print(f'Early stopping triggered at epoch {ep + 1} '
                              f'(no improvement for {patience} epochs, best val_loss={best_val_loss:.4f})')
                    stopped_epoch = ep + 1
                    break

    if early_stopping and restore_best and best_state is not None:
        model.load_state_dict(best_state)
        if verbose:
            print(f'Restored model weights from best epoch (val_loss={best_val_loss:.4f})')

    hist['stopped_epoch'] = stopped_epoch
    return hist

# %%
class_indices_arr = np.array(class_indices)

ft_results = {}

# Take only fold 0
fold, train_samples, val_samples, train_idx, val_idx = fold_splits[0]

torch.manual_seed(42)
train_dataset = stackedImageLoader(train_samples, transform=best_aug_transform, synchronized=True)
val_dataset      = stackedImageLoader(val_samples, transform=val_transform)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True,  num_workers=0, pin_memory=True)
val_loader   = DataLoader(val_dataset,       batch_size=64, shuffle=False, num_workers=0, pin_memory=True)

# Linear Probing
print('Step 1: Linear Probing')
# Fresh model
model_tfl = build_tfl_model(freeze_base=True, dropout=0.0, num_classes=len(CLASS_NAMES))

# Define optimiser
optimizer = torch.optim.Adam(
    filter(lambda p: p.requires_grad, model_tfl.parameters()), 
    lr=best_lr, 
    weight_decay=best_wd
)

# Class weights, computed from fold 0's train labels only
fold_train_targets = class_indices_arr[train_idx]
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.arange(len(CLASS_NAMES)),
    y=fold_train_targets
)
class_weights_tensor = torch.tensor(class_weights, dtype=torch.float32).to(device)
criterion = nn.CrossEntropyLoss(weight=class_weights_tensor)

# Train
ft_results['linear_probing'] = train_and_track(
    model_tfl, train_loader, val_loader,
    epochs=10, lr=best_lr,
    criterion=criterion,
    optimizer=optimizer
)
# Out:
# Step 1: Linear Probing
# ep  1/10  loss 2.325  f1 0.214  acc 0.258  |  val_loss 1.730  val_f1 0.429  val_acc 0.486  val_prec 0.417  val_rec 0.503  val_auc 0.908
# ep  2/10  loss 1.396  f1 0.523  acc 0.540  |  val_loss 1.025  val_f1 0.559  val_acc 0.575  val_prec 0.583  val_rec 0.598  val_auc 0.958
# ep  3/10  loss 0.799  f1 0.718  acc 0.718  |  val_loss 0.649  val_f1 0.741  val_acc 0.735  val_prec 0.755  val_rec 0.749  val_auc 0.978
# ep  4/10  loss 0.480  f1 0.829  acc 0.826  |  val_loss 0.459  val_f1 0.809  val_acc 0.807  val_prec 0.827  val_rec 0.816  val_auc 0.987
# ep  5/10  loss 0.321  f1 0.897  acc 0.891  |  val_loss 0.447  val_f1 0.860  val_acc 0.845  val_prec 0.868  val_rec 0.868  val_auc 0.987
# ep  6/10  loss 0.201  f1 0.939  acc 0.935  |  val_loss 0.322  val_f1 0.872  val_acc 0.867  val_prec 0.915  val_rec 0.890  val_auc 0.991
# ep  7/10  loss 0.150  f1 0.949  acc 0.946  |  val_loss 0.324  val_f1 0.864  val_acc 0.856  val_prec 0.885  val_rec 0.864  val_auc 0.994
# ...

# %% [markdown]
# Fine-tuning implementation derived from Week 6 Lecture Notebook

# %%
# Step 2: Fine-tuning (continue from the same model)
print('\nStep 2: Fine-Tuning')

FINE_TUNE_FROM = 14

for i, block in enumerate(model_tfl.backbone.features):
    for p in block.parameters():
        p.requires_grad = (i >= FINE_TUNE_FROM)

trainable = sum(p.numel() for p in model_tfl.parameters() if p.requires_grad)
total     = sum(p.numel() for p in model_tfl.parameters())
print(f'Unfroze features[{FINE_TUNE_FROM}:]  ->  trainable / total = {trainable:,} / {total:,}')

fine_tune_lr = best_lr/10

optimizer = torch.optim.Adam(
    filter(lambda p: p.requires_grad, model_tfl.parameters()), 
    lr=fine_tune_lr, 
    weight_decay=best_wd
)

# Train
ft_results['linear probing + fine tuning'] = train_and_track(
    model_tfl, train_loader, val_loader,
    epochs=10, lr=fine_tune_lr,
    criterion=criterion,
    optimizer=optimizer
)
# Out:
# Step 2: Fine-Tuning
# Unfroze features[14:]  ->  trainable / total = 1,697,997 / 2,243,981
# ep  1/10  loss 0.084  f1 0.979  acc 0.978  |  val_loss 0.214  val_f1 0.932  val_acc 0.928  val_prec 0.934  val_rec 0.940  val_auc 0.997
# ep  2/10  loss 0.060  f1 0.991  acc 0.990  |  val_loss 0.241  val_f1 0.930  val_acc 0.928  val_prec 0.931  val_rec 0.939  val_auc 0.996
# ep  3/10  loss 0.066  f1 0.984  acc 0.985  |  val_loss 0.260  val_f1 0.914  val_acc 0.912  val_prec 0.912  val_rec 0.923  val_auc 0.995
# ep  4/10  loss 0.059  f1 0.978  acc 0.977  |  val_loss 0.253  val_f1 0.926  val_acc 0.923  val_prec 0.924  val_rec 0.933  val_auc 0.996
# Early stopping triggered at epoch 4 (no improvement for 3 epochs, best val_loss=0.2140)
# Restored model weights from best epoch (val_loss=0.2140)

# %%
# Plot wd
plot_experiments(ft_results)

# Store in all_results
all_results['v4: +Aug+Lr+Wd+Es+Ft'] = ft_results['linear probing + fine tuning']

# %% [markdown]
# **Observations:**
# - The best-performing model is derived at ep=7 (loss=0.284, f1=0.900), and is used for fine-tuning
# - In fine tuning, the best performing model was recorded at ep=2 with the lowest validation loss and highest validation f1 score out of all models experimented in hyperparameter tuning.
# - At ep=2 of fine tuning, model properly fits with a train and validation f1 score difference of 0.047

# %% [markdown]
# ## Model after hyperparameter tuning
# - Data augmentation: Strong augmentation
# - Learning rate: 0.001
# - Weight regularisation: 0.0001
# - With fine-tuning and early stoppage

# %% [markdown]
# ## Model Analysis

# %% [markdown]
# After hyperparameter tuning, the best-performing model is retrained across 5 folds for K-fold cross validation. Similar to the baseline model analysis, metrics such as loss, accuracy, f1 score, precision, recall, and auc (area under curve) are averaged across all five folds.
#
# Model analysis is performed on the validation set rather than the test set in order to perform any adjustments to the model in response to any performance issues present in this stage (i.e. overfitting, output metric below target)
#
# After retraining, the model's results are expressed as a classification table and a confusion matrix.

# %% [markdown]
# ### Model retraining

# %%
from sklearn.utils.class_weight import compute_class_weight
# Best hyperparemeters
# Strong Augmentation
# lr = 0.001
# wd = 0.0001
# w/ fine tuning
all_preds_cv, all_labels_cv = [], []
m_best = {}
class_indices_arr = np.array(class_indices)

for fold, train_samples, val_samples, train_idx, val_idx in fold_splits:
    print(f"========== Fold {fold + 1} ==========")
    torch.manual_seed(42)
    train_dataset = stackedImageLoader(train_samples, transform=best_aug_transform, synchronized=True)
    val_dataset   = stackedImageLoader(val_samples, transform=val_transform)
    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True,  num_workers=0, pin_memory=True)
    val_loader   = DataLoader(val_dataset,   batch_size=64, shuffle=False, num_workers=0, pin_memory=True)

    # Fresh model each fold
    model_tfl = build_tfl_model(freeze_base=True, dropout=0.0, num_classes=len(CLASS_NAMES))

    # Linear Probing
    print('Step 1: Linear Probing')
    # Fresh model
    model_tfl = build_tfl_model(freeze_base=True, dropout=0.0, num_classes=len(CLASS_NAMES))
    
    # Define optimiser
    optimizer = torch.optim.Adam(
        filter(lambda p: p.requires_grad, model_tfl.parameters()), 
        lr=best_lr, 
        weight_decay=best_wd
    )
    
    # Compute class weights for this fold
    fold_train_targets = class_indices_arr[train_idx]
    class_weights = compute_class_weight(
        class_weight='balanced',
        classes=np.arange(len(CLASS_NAMES)),
        y=fold_train_targets
    )
    class_weights_tensor = torch.tensor(class_weights, dtype=torch.float32).to(device)
    criterion = nn.CrossEntropyLoss(weight=class_weights_tensor)

    fold_key = f'Model_tfl_fold{fold + 1}'

    # Train head
    m_best[fold_key] = train_and_track(
        model_tfl, train_loader, val_loader,
        epochs=10, lr=best_lr,
        criterion=criterion
    )

    # Step 2: Fine-tuning (continue from the same model)
    print('\nStep 2: Fine-Tuning')
    
    FINE_TUNE_FROM = 14
    
    for i, block in enumerate(model_tfl.backbone.features):
        for p in block.parameters():
            p.requires_grad = (i >= FINE_TUNE_FROM)
    
    trainable = sum(p.numel() for p in model_tfl.parameters() if p.requires_grad)
    total     = sum(p.numel() for p in model_tfl.parameters())
    print(f'Unfroze features[{FINE_TUNE_FROM}:]  ->  trainable / total = {trainable:,} / {total:,}')
    
    fine_tune_lr = best_lr/10
    
    optimizer = torch.optim.Adam(
        filter(lambda p: p.requires_grad, model_tfl.parameters()), 
        lr=fine_tune_lr, 
        weight_decay=best_wd
    )
    
    # Train head
    m_best[fold_key] = train_and_track(
        model_tfl, train_loader, val_loader,
        epochs=10, lr=fine_tune_lr,
        criterion=criterion,
        optimizer=optimizer
    )

    model_tfl.eval()
    with torch.inference_mode():
        for x, y in val_loader:
            x = x.to(device)
            _, predicted = torch.max(model_tfl(x), 1)
            all_preds_cv.extend(predicted.cpu().numpy())
            all_labels_cv.extend(y.numpy())

all_preds_cv = np.array(all_preds_cv)
all_labels_cv = np.array(all_labels_cv)
# Out:
# ========== Fold 1 ==========
# Step 1: Linear Probing
# ep  1/10  loss 2.385  f1 0.200  acc 0.223  |  val_loss 1.832  val_f1 0.324  val_acc 0.396  val_prec 0.366  val_rec 0.389  val_auc 0.891
# ep  2/10  loss 1.489  f1 0.551  acc 0.565  |  val_loss 1.031  val_f1 0.530  val_acc 0.582  val_prec 0.561  val_rec 0.570  val_auc 0.951
# ep  3/10  loss 0.830  f1 0.738  acc 0.742  |  val_loss 0.719  val_f1 0.624  val_acc 0.681  val_prec 0.651  val_rec 0.663  val_auc 0.973
# ep  4/10  loss 0.428  f1 0.869  acc 0.861  |  val_loss 0.445  val_f1 0.815  val_acc 0.813  val_prec 0.862  val_rec 0.807  val_auc 0.987
# ep  5/10  loss 0.257  f1 0.925  acc 0.919  |  val_loss 0.488  val_f1 0.788  val_acc 0.802  val_prec 0.808  val_rec 0.793  val_auc 0.987
# ep  6/10  loss 0.166  f1 0.953  acc 0.950  |  val_loss 0.392  val_f1 0.843  val_acc 0.852  val_prec 0.868  val_rec 0.851  val_auc 0.991
# ...

# %% [markdown]
# ### Classification Report

# %%
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
print(classification_report(all_labels_cv, all_preds_cv, target_names=CLASS_NAMES, zero_division=0))
# Out:
#                   precision    recall  f1-score   support
#
#         AllClear       0.79      0.81      0.80        72
#      HaveCommand       0.93      0.93      0.93        73
#            Hover       1.00      1.00      1.00        69
#             Land       1.00      1.00      1.00       106
# LandingDirection       1.00      1.00      1.00        41
#        MoveAhead       0.92      0.92      0.92        84
#     MoveDownward       0.98      1.00      0.99        40
#       MoveToLeft       0.99      0.98      0.98        82
#      MoveToRight       0.97      0.97      0.97        80
#       MoveUpward       0.98      0.96      0.97        54
#         NotClear       0.82      0.81      0.82        74
#         SlowDown       0.91      0.91      0.91        80
#          WaveOff       0.98      1.00      0.99        53
#
#         accuracy                           0.94       908
#        macro avg       0.94      0.95      0.94       908
# ...

# %% [markdown]
# ### Confusion Matrix

# %%
cm = confusion_matrix(all_labels_cv, all_preds_cv)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=CLASS_NAMES)
fig, ax = plt.subplots(figsize=(10, 8))
disp.plot(ax=ax, xticks_rotation=45, cmap='Blues', colorbar=False)
plt.title('Confusion Matrix — Pooled Cross-Validation Predictions')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Error Analysis

# %%
val_transform_vis = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
])

# Rebuild val_dataset WITHOUT augmentation/normalization, for correct visual display
val_dataset_vis = stackedImageLoader(val_samples, transform=val_transform_vis, synchronized=False)
# val_transform_vis should be resize + ToTensor ONLY (no Normalize), so pixel values display correctly

errors = np.where(all_preds_cv != all_labels_cv)[0]
print(f'Misclassified: {len(errors)} / {len(all_labels_cv)} ({len(errors)/len(all_labels_cv)*100:.1f}%)')

n_show = min(8, len(errors))  # 8 instances, each shown as a row of 5 frames

fig, axes = plt.subplots(n_show, 5, figsize=(14, 2.5 * n_show))
if n_show == 1:
    axes = axes[np.newaxis, :]

for row, err_idx in enumerate(errors[:n_show]):
    clip, true_label = val_dataset_vis[err_idx]  # clip: (5, C, H, W)
    group_key = val_dataset_vis.instances[err_idx][2]  # retrieve the instance's group_key for context

    pred_label = all_preds_cv[err_idx]

    for col in range(clip.shape[0]):
        frame = clip[col].permute(1, 2, 0).numpy()
        axes[row, col].imshow(np.clip(frame, 0, 1))
        axes[row, col].axis('off')
        if col == 0:
            axes[row, col].text(
                -0.3, 0.5,
                f'True: {CLASS_NAMES[true_label]}\nPred: {CLASS_NAMES[pred_label]}\n{group_key}',
                fontsize=8, va='center', ha='right', transform=axes[row, col].transAxes
            )

plt.suptitle('Misclassified Instances (5 frames each)', fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# Misclassified: 53 / 908 (5.8%)

# %% [markdown]
# ### Observations / Comments

# %% [markdown]
# - The model was able to classify the instances of almost all classes, with an unweighted f1 score of 0.94 with only 5.4% misclassifications.
# - The most common confusion is the AllClear ↔ NotClear pair, having an f1 score of 0.80 and 0.82 respectively. Instances of both classes share very similar poses/frames, starting and ending with arms on the side and waving the right arm down and up on the side.
# - MoveAhead ↔ SlowDown are also confused with each other, both containing the arms forward action within the instance.
#     - For two instances, SlowDown was also confused for HaveCommand, which can be attributed by the model misreading a single arm as both arms.
# - There are cases where MoveRight being misclassified with MoveLeft and vice-versa. The most likely cause is from the image rotation from data augmentation, which may have confused the model. This is especially a risk if a single/several frames were taken at an angle and the augmentation further emphasise the rotation.
# - Most misclassifications can be attributed to gesture classes having very similar frames within an instance (i.e. AllClear ↔ NotClear, MoveAhead ↔ SlowDown). Other causes may include data augmentation, subject error, and shooting conditions.

# %% [markdown]
# ## Final Evaluation

# %% [markdown]
# After analysis, the model can now be evaluated against the test set using hold-out validation. For the model used for the final evaluation, the model will be trained off the full trainval set. This is done by allocating 15% of the trainval set and utilising for early stoppage.

# %%
def stratified_group_holdout_split(all_samples, class_indices, groups, trainval_idx, val_size=0.2, random_state=42):
    """
    Performs a single stratified-group train/val hold-out split over the trainval pool
    (instance-grouped, class-stratified). Returns (train_samples, val_samples, train_idx, val_idx).
    Indices returned are into the ORIGINAL all_samples/class_indices/groups arrays.
    """
    all_samples = np.array(all_samples, dtype=object)
    class_indices = np.array(class_indices)
    groups = np.array(groups)

    tv_samples = all_samples[trainval_idx]
    tv_classes = class_indices[trainval_idx]
    tv_groups = groups[trainval_idx]

    n_splits = max(2, round(1 / val_size))  # e.g. val_size=0.2 -> n_splits=5, take 1 fold as val
    sgkf = StratifiedGroupKFold(n_splits=n_splits, shuffle=True, random_state=random_state)

    # Take only the FIRST split instead of looping through all n_splits
    train_sub_idx, val_sub_idx = next(sgkf.split(tv_samples, tv_classes, tv_groups))

    train_idx = trainval_idx[train_sub_idx]
    val_idx = trainval_idx[val_sub_idx]

    train_samples = [(all_samples[i][0], class_indices[i], groups[i]) for i in train_idx]
    val_samples   = [(all_samples[i][0], class_indices[i], groups[i]) for i in val_idx]

    # Sanity check: no group leakage between train/val
    g_train, g_val = set(groups[train_idx]), set(groups[val_idx])
    assert not (g_train & g_val), f"Leakage train/val: {g_train & g_val}"

    print(f"Train: {len(train_samples)} images across {len(g_train)} instances")
    print(f"Val:   {len(val_samples)} images across {len(g_val)} instances")

    return train_samples, val_samples, train_idx, val_idx

# %%
train_samples, val_samples, train_idx, val_idx = stratified_group_holdout_split(
    samples, class_indices, groups, trainval_idx, val_size=0.15, random_state=42
)
# Out:
# Train: 3885 images across 777 instances
# Val:   650 images across 130 instances

# %% [markdown]
# ### Retraining the model

# %%
# Placeholder {} for training
placeholder = {}

torch.manual_seed(42)
train_dataset = stackedImageLoader(train_samples, transform=best_aug_transform, synchronized=True)
val_dataset      = stackedImageLoader(val_samples, transform=val_transform)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True,  num_workers=0, pin_memory=True)
val_loader   = DataLoader(val_dataset,       batch_size=64, shuffle=False, num_workers=0, pin_memory=True)

# Linear Probing
print('Step 1: Linear Probing')
# Fresh model
model_tfl = build_tfl_model(freeze_base=True, dropout=0.0, num_classes=len(CLASS_NAMES))

# Define optimiser
optimizer = torch.optim.Adam(
    filter(lambda p: p.requires_grad, model_tfl.parameters()), 
    lr=best_lr, 
    weight_decay=best_wd
)

# Class weights, computed from fold 0's train labels only
fold_train_targets = class_indices_arr[train_idx]
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.arange(len(CLASS_NAMES)),
    y=fold_train_targets
)
class_weights_tensor = torch.tensor(class_weights, dtype=torch.float32).to(device)
criterion = nn.CrossEntropyLoss(weight=class_weights_tensor)

# Train
placeholder['linear probing'] = train_and_track(
    model_tfl, train_loader, val_loader,
    epochs=10, lr=best_lr,
    criterion=criterion,
    optimizer=optimizer
)

# Step 2: Fine-tuning (continue from the same model)
print('\nStep 2: Fine-Tuning')

FINE_TUNE_FROM = 14

for i, block in enumerate(model_tfl.backbone.features):
    for p in block.parameters():
        p.requires_grad = (i >= FINE_TUNE_FROM)

trainable = sum(p.numel() for p in model_tfl.parameters() if p.requires_grad)
total     = sum(p.numel() for p in model_tfl.parameters())
print(f'Unfroze features[{FINE_TUNE_FROM}:]  ->  trainable / total = {trainable:,} / {total:,}')

fine_tune_lr = best_lr/10

optimizer = torch.optim.Adam(
    filter(lambda p: p.requires_grad, model_tfl.parameters()), 
    lr=fine_tune_lr, 
    weight_decay=best_wd
)

# Train
placeholder['linear probing + fine tuning'] = train_and_track(
    model_tfl, train_loader, val_loader,
    epochs=10, lr=fine_tune_lr,
    criterion=criterion,
    optimizer=optimizer
)
# Out:
# Step 1: Linear Probing
# ep  1/10  loss 2.343  f1 0.208  acc 0.249  |  val_loss 1.848  val_f1 0.361  val_acc 0.409  val_prec 0.364  val_rec 0.442  val_auc 0.883
# ep  2/10  loss 1.436  f1 0.514  acc 0.539  |  val_loss 1.090  val_f1 0.511  val_acc 0.519  val_prec 0.646  val_rec 0.565  val_auc 0.952
# ep  3/10  loss 0.823  f1 0.720  acc 0.719  |  val_loss 0.736  val_f1 0.710  val_acc 0.718  val_prec 0.764  val_rec 0.726  val_auc 0.973
# ep  4/10  loss 0.504  f1 0.815  acc 0.807  |  val_loss 0.435  val_f1 0.827  val_acc 0.834  val_prec 0.884  val_rec 0.840  val_auc 0.988
# ep  5/10  loss 0.345  f1 0.865  acc 0.860  |  val_loss 0.399  val_f1 0.865  val_acc 0.851  val_prec 0.872  val_rec 0.870  val_auc 0.989
# ep  6/10  loss 0.233  f1 0.921  acc 0.920  |  val_loss 0.441  val_f1 0.822  val_acc 0.823  val_prec 0.868  val_rec 0.828  val_auc 0.990
# ep  7/10  loss 0.206  f1 0.928  acc 0.927  |  val_loss 0.314  val_f1 0.861  val_acc 0.862  val_prec 0.878  val_rec 0.866  val_auc 0.993

# %% [markdown]
# ### Test model

# %%
from sklearn.metrics import f1_score

def evaluate(model, loader, criterion):
    model.eval()
    total_loss, correct, total = 0.0, 0, 0
    all_preds, all_labels = [], []

    with torch.inference_mode():
        for x, y in loader:
            x, y = x.to(device), y.to(device)
            outputs = model(x)
            loss = criterion(outputs, y)
            total_loss += loss.item() * y.size(0)
            _, predicted = torch.max(outputs, 1)
            correct += (predicted == y).sum().item()
            total += y.size(0)

            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(y.cpu().numpy())

    f1 = f1_score(all_labels, all_preds, average='macro', zero_division=0)
    return total_loss / total, correct / total, f1

# %%
test_dataset = stackedImageLoader(test_samples, transform=val_transform)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False, num_workers=0, pin_memory=True)

test_loss, test_acc, test_f1 = evaluate(model_tfl, test_loader, nn.CrossEntropyLoss())

# %% [markdown]
# ## Reflection

# %% [markdown]
# ### Limitation Analysis

# %% [markdown]
# ---

# %% [markdown]
# # Part B - The recommendation

# %% [markdown]
# -

# %% [markdown]
# # References
# - GeeksForGeeks (2025) What is Data Augmentation? How Does Data Augmentation Work for Images?, GeeksForGeeks website, accessed 31 August 2026 https://www.geeksforgeeks.org/deep-learning/early-fusion-vs-late-fusion-in-multimodal-data-processing/
# - ML4Devs (2026) Dropout and Regularization: Preventing Overfitting, ML4Devs website, accessed 3 September 2026 https://www.ml4devs.com/what-is/dropout-regularization/
